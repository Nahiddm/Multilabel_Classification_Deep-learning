# %% [markdown]
# # IMPORT

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, Bidirectional, LSTM, Dense
from tensorflow.keras.utils import to_categorical
# Out:
# WARNING:tensorflow:From C:\Users\Legion\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## PRAPROSES ( TOKENEZIR, PADDING, SPLIT DATA)

# %%
# Load the dataset
data_path = 'augmentasifix.xlsx'
data = pd.read_excel(data_path)

# praproses
texts = data['formal_text'].astype(str).values
tokenizer = Tokenizer(num_words=5000) # aktual 30k
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
word_index = tokenizer.word_index
data_padded = pad_sequences(sequences, maxlen=50)

# asumsi labell
label_columns = ['anger', 'anticipation', 'disgust', 'fear', 'joy', 'sadness', 'surprise', 'trust','anies','prabowo','ganjar']
labels = data[label_columns].values

# Split data
#X_train, X_test, y_train, y_test = train_test_split(data_padded, labels, test_size=0.2, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(
    data_padded, labels, test_size=0.2, random_state=42, shuffle=True,)
indices_train, indices_test = train_test_split(
    data.index, test_size=0.2, random_state=42, shuffle=True)

# %%
text_lengths = [len(text.split()) for text in texts]
print(np.mean(text_lengths))
# Out:
# 14.113533662356053

# %% [markdown]
# ## CEK DISTRIBUSI LABEL

# %%
import matplotlib.pyplot as plt

# Count frequency of 1s in each column
label_frequencies = np.sum(labels, axis=0)
for label, label_freq in zip(label_columns, label_frequencies):
    print(f"{label}: {label_freq}")

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(range(len(label_frequencies)), label_frequencies)
plt.xlabel("Label Index")
plt.ylabel("Frequency")
plt.title("Frequency of 1s in Each Label (Column)")
plt.show()
# Out:
# anger: 23091
# anticipation: 4614
# disgust: 25740
# fear: 6567
# joy: 35601
# sadness: 5703
# surprise: 8550
# trust: 36531
# anies: 24092
# prabowo: 20568
# ganjar: 7591

# %% [markdown]
# ## IMPLEMENTASI CLASS WEIGHT
#
# Cara Kerja: class_weight menyesuaikan bobot kesalahan (loss) yang diterima selama pelatihan model berdasarkan frekuensi label. Bobot yang lebih tinggi diberikan kepada kelas yang lebih jarang, yang berarti bahwa kesalahan dalam memprediksi label minoritas akan memiliki dampak yang lebih besar pada pembelajaran model, seolah-olah ada lebih banyak contoh dari kelas tersebut.
# Efek pada Data: Tidak ada perubahan fisik pada data; hanya fungsi loss yang dimodifikasi untuk mengkompensasi ketidakseimbangan.

# %%
class_weight = {}
for idx, label_freq in enumerate(label_frequencies):
    class_weight[idx] = (1 / label_freq) * (label_frequencies.sum() / 2)
    
class_weight
# Out:
# {0: 4.301416136156944,
#  1: 21.52665799739922,
#  2: 3.858741258741259,
#  3: 15.1247144814984,
#  4: 2.7899216314148476,
#  5: 17.41609679116255,
#  6: 11.616842105263158,
#  7: 2.7188962798718896,
#  8: 4.122696330732193,
#  9: 4.829054842473746,
#  10: 13.08444210248979}

# %% [markdown]
# ## MODEL

# %%
from keras.models import Sequential
from keras.layers import Embedding, Conv1D, MaxPooling1D, Dense, Dropout, GlobalMaxPooling1D

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC, Precision, Recall
from keras import optimizers



model = Sequential()
model.add(Embedding(len(word_index) + 1, 64))
model.add(Dropout(0.1))
model.add(Conv1D(16, 5, activation='relu'))  # Ubah filters dan kernel_size sesuai kebutuhan
model.add(MaxPooling1D(pool_size=4))
model.add(Bidirectional(LSTM(16, return_sequences=True)))
model.add(Dropout(0.1))
model.add(Bidirectional(LSTM(16)))
model.add(Dropout(0.1))
model.add(Dense(len(label_columns), activation='sigmoid'))
model.add(Dropout(0.1))


early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

lr_schedule = optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=10000,
    decay_rate=0.9)

optimizer = optimizers.Adam(learning_rate=lr_schedule)

model.compile(
    loss='binary_crossentropy',
    optimizer=optimizer,
    metrics=['accuracy', AUC(multi_label=True), Precision(), Recall()])

print(model.summary())
# Out:
# WARNING:tensorflow:From C:\Users\Legion\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Legion\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 64)          1946944
#
#  dropout (Dropout)           (None, None, 64)          0
#
#  conv1d (Conv1D)             (None, None, 16)          5136
#
#  max_pooling1d (MaxPooling1  (None, None, 16)          0
#  D)
#
#  bidirectional (Bidirection  (None, None, 32)          4224
#  al)
#
#  dropout_1 (Dropout)         (None, None, 32)          0
#
#  bidirectional_1 (Bidirecti  (None, 32)                6272
#  onal)
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 11)                363
#
#  dropout_3 (Dropout)         (None, 11)                0
#
# =================================================================
# Total params: 1962939 (7.49 MB)
# Trainable params: 1962939 (7.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=128,
    class_weight=class_weight,
    callbacks=early_stopping
)

# Menyimpan model
model.save('modelCNNBi-LSTM80/20.h5')
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Legion\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Legion\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 601/601 [==============================] - 29s 33ms/step - loss: 3.6379 - accuracy: 0.1379 - auc: 0.5882 - precision: 0.4700 - recall: 0.1105 - val_loss: 0.4006 - val_accuracy: 0.1674 - val_auc: 0.7076 - val_precision: 0.7884 - val_recall: 0.1551
# Epoch 2/50
# 601/601 [==============================] - 21s 35ms/step - loss: 3.3440 - accuracy: 0.1753 - auc: 0.6905 - precision: 0.7586 - recall: 0.2681 - val_loss: 0.3481 - val_accuracy: 0.2090 - val_auc: 0.7755 - val_precision: 0.8373 - val_recall: 0.3275
# Epoch 3/50
# 601/601 [==============================] - 20s 32ms/step - loss: 3.1334 - accuracy: 0.2005 - auc: 0.7322 - precision: 0.7677 - recall: 0.3697 - val_loss: 0.3311 - val_accuracy: 0.2143 - val_auc: 0.7989 - val_precision: 0.8430 - val_recall: 0.3737
# Epoch 4/50
# 601/601 [==============================] - 20s 33ms/step - loss: 3.0705 - accuracy: 0.2122 - auc: 0.7508 - precision: 0.7683 - recall: 0.4142 - val_loss: 0.3243 - val_accuracy: 0.2339 - val_auc: 0.8102 - val_precision: 0.7981 - val_recall: 0.4286
# Epoch 5/50
# 601/601 [==============================] - 19s 32ms/step - loss: 3.0165 - accuracy: 0.2271 - auc: 0.7626 - precision: 0.7752 - recall: 0.4357 - val_loss: 0.3182 - val_accuracy: 0.2236 - val_auc: 0.8184 - val_precision: 0.7892 - val_recall: 0.4532
# Epoch 6/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.9596 - accuracy: 0.2338 - auc: 0.7748 - precision: 0.7798 - recall: 0.4586 - val_loss: 0.3164 - val_accuracy: 0.2313 - val_auc: 0.8262 - val_precision: 0.8019 - val_recall: 0.4493
# Epoch 7/50
# 601/601 [==============================] - 19s 32ms/step - loss: 2.8988 - accuracy: 0.2365 - auc: 0.7851 - precision: 0.7885 - recall: 0.4761 - val_loss: 0.3093 - val_accuracy: 0.2197 - val_auc: 0.8317 - val_precision: 0.7909 - val_recall: 0.4761
# Epoch 8/50
# 601/601 [==============================] - 19s 32ms/step - loss: 2.8699 - accuracy: 0.2369 - auc: 0.7914 - precision: 0.7941 - recall: 0.4900 - val_loss: 0.3094 - val_accuracy: 0.2480 - val_auc: 0.8339 - val_precision: 0.7860 - val_recall: 0.4776
# Epoch 9/50
# 601/601 [==============================] - 19s 32ms/step - loss: 2.8212 - accuracy: 0.2461 - auc: 0.7994 - precision: 0.8016 - recall: 0.5047 - val_loss: 0.3054 - val_accuracy: 0.2202 - val_auc: 0.8363 - val_precision: 0.7873 - val_recall: 0.5111
# Epoch 10/50
# 601/601 [==============================] - 19s 32ms/step - loss: 2.7751 - accuracy: 0.2432 - auc: 0.8054 - precision: 0.8091 - recall: 0.5150 - val_loss: 0.3022 - val_accuracy: 0.1653 - val_auc: 0.8393 - val_precision: 0.7918 - val_recall: 0.5025
# Epoch 11/50
# 601/601 [==============================] - 19s 32ms/step - loss: 2.7677 - accuracy: 0.2417 - auc: 0.8099 - precision: 0.8136 - recall: 0.5201 - val_loss: 0.3013 - val_accuracy: 0.2058 - val_auc: 0.8397 - val_precision: 0.7933 - val_recall: 0.5015
# Epoch 12/50
# 601/601 [==============================] - 20s 32ms/step - loss: 2.7931 - accuracy: 0.2641 - auc: 0.8064 - precision: 0.8162 - recall: 0.5018 - val_loss: 0.3030 - val_accuracy: 0.2779 - val_auc: 0.8405 - val_precision: 0.8021 - val_recall: 0.4894
# Epoch 13/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.7164 - accuracy: 0.2926 - auc: 0.8166 - precision: 0.8181 - recall: 0.5302 - val_loss: 0.2986 - val_accuracy: 0.2114 - val_auc: 0.8427 - val_precision: 0.7981 - val_recall: 0.5112
# Epoch 14/50
# 601/601 [==============================] - 19s 32ms/step - loss: 2.7010 - accuracy: 0.2790 - auc: 0.8196 - precision: 0.8218 - recall: 0.5427 - val_loss: 0.2996 - val_accuracy: 0.2481 - val_auc: 0.8442 - val_precision: 0.7947 - val_recall: 0.5143
# Epoch 15/50
# 601/601 [==============================] - 19s 32ms/step - loss: 2.6741 - accuracy: 0.2766 - auc: 0.8223 - precision: 0.8274 - recall: 0.5430 - val_loss: 0.2986 - val_accuracy: 0.2634 - val_auc: 0.8451 - val_precision: 0.7875 - val_recall: 0.5172
# Epoch 16/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.6816 - accuracy: 0.2661 - auc: 0.8228 - precision: 0.8298 - recall: 0.5472 - val_loss: 0.2952 - val_accuracy: 0.2630 - val_auc: 0.8455 - val_precision: 0.7919 - val_recall: 0.5268
# Epoch 17/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.6506 - accuracy: 0.2719 - auc: 0.8286 - precision: 0.8314 - recall: 0.5526 - val_loss: 0.2940 - val_accuracy: 0.2357 - val_auc: 0.8465 - val_precision: 0.7907 - val_recall: 0.5291
# Epoch 18/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.6041 - accuracy: 0.2775 - auc: 0.8312 - precision: 0.8356 - recall: 0.5587 - val_loss: 0.3000 - val_accuracy: 0.2489 - val_auc: 0.8452 - val_precision: 0.7891 - val_recall: 0.5236
# Epoch 19/50
# 601/601 [==============================] - 19s 32ms/step - loss: 2.6286 - accuracy: 0.2742 - auc: 0.8322 - precision: 0.8362 - recall: 0.5611 - val_loss: 0.2955 - val_accuracy: 0.2603 - val_auc: 0.8460 - val_precision: 0.7856 - val_recall: 0.5354
# Epoch 20/50
# 601/601 [==============================] - 19s 32ms/step - loss: 2.6799 - accuracy: 0.2816 - auc: 0.8262 - precision: 0.8352 - recall: 0.5438 - val_loss: 0.2990 - val_accuracy: 0.2745 - val_auc: 0.8454 - val_precision: 0.7917 - val_recall: 0.5215
# Epoch 21/50
# 601/601 [==============================] - 19s 32ms/step - loss: 2.6340 - accuracy: 0.2761 - auc: 0.8329 - precision: 0.8382 - recall: 0.5610 - val_loss: 0.3011 - val_accuracy: 0.2531 - val_auc: 0.8424 - val_precision: 0.8056 - val_recall: 0.5031
# Epoch 22/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.6051 - accuracy: 0.2994 - auc: 0.8357 - precision: 0.8463 - recall: 0.5576 - val_loss: 0.2971 - val_accuracy: 0.2788 - val_auc: 0.8463 - val_precision: 0.8017 - val_recall: 0.5171
# Epoch 23/50
# 601/601 [==============================] - 19s 32ms/step - loss: 2.5865 - accuracy: 0.3072 - auc: 0.8365 - precision: 0.8431 - recall: 0.5675 - val_loss: 0.2965 - val_accuracy: 0.2730 - val_auc: 0.8452 - val_precision: 0.7930 - val_recall: 0.5300
# Epoch 24/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.5774 - accuracy: 0.2996 - auc: 0.8385 - precision: 0.8449 - recall: 0.5707 - val_loss: 0.3000 - val_accuracy: 0.2644 - val_auc: 0.8478 - val_precision: 0.7840 - val_recall: 0.5364
# Epoch 25/50
# 601/601 [==============================] - 19s 32ms/step - loss: 2.5653 - accuracy: 0.2957 - auc: 0.8411 - precision: 0.8460 - recall: 0.5759 - val_loss: 0.3040 - val_accuracy: 0.2495 - val_auc: 0.8468 - val_precision: 0.7831 - val_recall: 0.5147
# Epoch 26/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.5597 - accuracy: 0.2911 - auc: 0.8424 - precision: 0.8469 - recall: 0.5754 - val_loss: 0.3000 - val_accuracy: 0.2452 - val_auc: 0.8473 - val_precision: 0.7872 - val_recall: 0.5316
# Epoch 27/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.5698 - accuracy: 0.2867 - auc: 0.8430 - precision: 0.8505 - recall: 0.5781 - val_loss: 0.3050 - val_accuracy: 0.2332 - val_auc: 0.8468 - val_precision: 0.7904 - val_recall: 0.5276
# Epoch 28/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.5595 - accuracy: 0.2870 - auc: 0.8434 - precision: 0.8515 - recall: 0.5785 - val_loss: 0.2980 - val_accuracy: 0.2557 - val_auc: 0.8465 - val_precision: 0.7883 - val_recall: 0.5367
# Epoch 29/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.5537 - accuracy: 0.2792 - auc: 0.8441 - precision: 0.8526 - recall: 0.5764 - val_loss: 0.2977 - val_accuracy: 0.2549 - val_auc: 0.8474 - val_precision: 0.7866 - val_recall: 0.5398
# Epoch 30/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.5303 - accuracy: 0.2897 - auc: 0.8461 - precision: 0.8533 - recall: 0.5846 - val_loss: 0.2986 - val_accuracy: 0.2595 - val_auc: 0.8476 - val_precision: 0.7862 - val_recall: 0.5372
# Epoch 31/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.5337 - accuracy: 0.2898 - auc: 0.8469 - precision: 0.8544 - recall: 0.5841 - val_loss: 0.2969 - val_accuracy: 0.2510 - val_auc: 0.8483 - val_precision: 0.7815 - val_recall: 0.5467
# Epoch 32/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.5441 - accuracy: 0.2904 - auc: 0.8469 - precision: 0.8566 - recall: 0.5833 - val_loss: 0.2958 - val_accuracy: 0.2545 - val_auc: 0.8474 - val_precision: 0.7874 - val_recall: 0.5399
# Epoch 33/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.4905 - accuracy: 0.2961 - auc: 0.8496 - precision: 0.8577 - recall: 0.5870 - val_loss: 0.2973 - val_accuracy: 0.2580 - val_auc: 0.8502 - val_precision: 0.7896 - val_recall: 0.5380
# Epoch 34/50
# 601/601 [==============================] - 19s 32ms/step - loss: 2.5084 - accuracy: 0.2988 - auc: 0.8510 - precision: 0.8570 - recall: 0.5918 - val_loss: 0.3010 - val_accuracy: 0.2616 - val_auc: 0.8486 - val_precision: 0.7836 - val_recall: 0.5415
# Epoch 35/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.4938 - accuracy: 0.2880 - auc: 0.8494 - precision: 0.8563 - recall: 0.5828 - val_loss: 0.2951 - val_accuracy: 0.2568 - val_auc: 0.8469 - val_precision: 0.7815 - val_recall: 0.5509
# Epoch 36/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.5172 - accuracy: 0.2980 - auc: 0.8496 - precision: 0.8599 - recall: 0.5817 - val_loss: 0.3033 - val_accuracy: 0.2636 - val_auc: 0.8448 - val_precision: 0.7832 - val_recall: 0.5143
# Epoch 37/50
# 601/601 [==============================] - 20s 33ms/step - loss: 2.5265 - accuracy: 0.3046 - auc: 0.8491 - precision: 0.8594 - recall: 0.5828 - val_loss: 0.2979 - val_accuracy: 0.2522 - val_auc: 0.8486 - val_precision: 0.7855 - val_recall: 0.5478
# C:\Users\Legion\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## EVALUASI MODEL

# %%
print(model.evaluate(X_test, y_test))
# Out:
# 601/601 [==============================] - 4s 6ms/step - loss: 0.2940 - accuracy: 0.2357 - auc: 0.8465 - precision: 0.7907 - recall: 0.5291
# [0.2939552366733551, 0.2356707751750946, 0.8465137481689453, 0.7906715869903564, 0.5290817022323608]

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
# Melakukan prediksi pada data validasi
y_pred = model.predict(X_test)


# Assuming y_pred_binary_adjusted has been computed based on an optimal threshold
for i, label in enumerate(label_columns):
    cm = confusion_matrix(y_test[:, i], y_pred[:, i] > 0.5)
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title(f'Confusion Matrix {label}')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.show()
# Out:
# 601/601 [==============================] - 5s 4ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score


# Menghitung akurasi, presisi, dan recall per label
metrics = {}
for i, label in enumerate(label_columns):
    label_pred = y_pred[:, i] > 0.5  # Menggunakan threshold 0.5 untuk binerisasi
    accuracy = accuracy_score(y_test[:, i], label_pred)
    precision = precision_score(y_test[:, i], label_pred)
    recall = recall_score(y_test[:, i], label_pred)
    metrics[label] = {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall
    }

# Mencetak akurasi, presisi, dan recall per label
for label, metric in metrics.items():
    print(f'Accuracy for label {label}: {metric["accuracy"]}')
    print(f'Precision for label {label}: {metric["precision"]}')
    print(f'Recall for label {label}: {metric["recall"]}')
    print()
# Out:
# Accuracy for label anger: 0.8217502212504555
# Precision for label anger: 0.68544
# Recall for label anger: 0.46737944577787477
#
# Accuracy for label anticipation: 0.936592222395752
# Precision for label anticipation: 0.3352803738317757
# Recall for label anticipation: 0.30662393162393164
#
# Accuracy for label disgust: 0.8033734187099797
# Precision for label disgust: 0.697089144936325
# Recall for label disgust: 0.4528264723261769
#
# Accuracy for label fear: 0.9397157582383258
# Precision for label fear: 0.6321243523316062
# Recall for label fear: 0.35829662261380324
#
# Accuracy for label joy: 0.7376750481545109
# Precision for label joy: 0.772020725388601
# Recall for label joy: 0.4174254097212495
#
# Accuracy for label sadness: 0.9417981154667083
# Precision for label sadness: 0.5848214285714286
# Recall for label sadness: 0.21943048576214405
#
# Accuracy for label surprise: 0.9145712947056067
# Precision for label surprise: 0.5657015590200446
# Recall for label surprise: 0.14941176470588236
#
# Accuracy for label trust: 0.7923889843302618
# Precision for label trust: 0.7910057521352624
# Recall for label trust: 0.6193530776579773
#
# Accuracy for label anies: 0.9308657400177001
# Precision for label anies: 0.9703446433342239
# Recall for label anies: 0.7490204165807383
#
# Accuracy for label prabowo: 0.9420063511895466
# Precision for label prabowo: 0.9892575039494471
# Recall for label prabowo: 0.743528853004037
#
# Accuracy for label ganjar: 0.9694414076734864
# Precision for label ganjar: 0.8794607454401269
# Recall for label ganjar: 0.7182642487046632

# %%
from sklearn.metrics import jaccard_score

# Menggabungkan semua prediksi dan label sebenarnya dalam satu dimensi
y_pred_flat = y_pred.ravel() > 0.5  # Menggunakan threshold 0.5 untuk binerisasi
y_test_flat = y_test.ravel()

# Menghitung skor Jaccard secara keseluruhan
jaccard_overall = jaccard_score(y_test_flat, y_pred_flat)

print(f'Overall Jaccard similarity: {jaccard_overall}')
# Out:
# Overall Jaccard similarity: 0.4640769873006108

# %%
loss, accuracy, auc, precision, recall = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}, Test Accuracy: {accuracy}')
print(f'Test AUC: {auc}, Test Precision:{precision}, Test Recall: {recall}')
# Out:
# 601/601 [==============================] - 4s 6ms/step - loss: 0.2940 - accuracy: 0.2357 - auc: 0.8465 - precision: 0.7907 - recall: 0.5291
# Test Loss: 0.2939552366733551, Test Accuracy: 0.2356707751750946
# Test AUC: 0.8465137481689453, Test Precision:0.7906715869903564, Test Recall: 0.5290817022323608

# %% [markdown]
# ### AUC DAN HAMMING LOSS

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_auc_score, roc_curve, hamming_loss
from sklearn.preprocessing import MultiLabelBinarizer

# Prediksi probabilitas dari model
y_pred_prob = model.predict(X_test)

# Hitung rata-rata AUC dari semua kelas
auc_scores = []
for i in range(len(label_columns)):
    auc_score = roc_auc_score(y_test[:, i], y_pred_prob[:, i])
    auc_scores.append(auc_score)

avg_auc = np.mean(auc_scores)

# Hitung kurva ROC secara keseluruhan
fpr_all, tpr_all, _ = roc_curve(y_test.ravel(), y_pred_prob.ravel())

# Plot ROC curve untuk keseluruhan
plt.figure(figsize=(10, 6))
plt.plot(fpr_all, tpr_all, label=f'Overall (Avg AUC = {avg_auc:.2f})', color='orange')

# Plot kurva ROC untuk setiap kelas
for i in range(len(label_columns)):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_prob[:, i])
    plt.plot(fpr, tpr, label=f'{label_columns[i]} (AUC = {auc_scores[i]:.2f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')

# Tampilkan teks untuk nilai AUC keseluruhan
plt.text(0.5, 0.1, f'Avg AUC = {avg_auc:.2f}', fontsize=12, ha='center')

plt.show()

# Tampilkan hasil AUC keseluruhan
print(f'Test AUC: {avg_auc:.2f}')

# Tentukan threshold untuk konversi probabilitas menjadi label biner
thresholds = np.arange(0.1, 1.0, 0.1)

# Inisialisasi list untuk menyimpan nilai Hamming Loss untuk setiap threshold
hamming_losses = []

# Hitung Hamming Loss untuk setiap threshold
for threshold in thresholds:
    # Konversi probabilitas prediksi menjadi label biner berdasarkan threshold
    y_pred_binary = (y_pred_prob >= threshold).astype(int)
    y_pred_binary_adjusted = y_pred_binary[:, :y_test.shape[1]]
    
    # Hitung Hamming Loss
    hamming_loss_value = hamming_loss(y_test, y_pred_binary_adjusted)
    hamming_losses.append(hamming_loss_value)
 # Cetak nilai Hamming Loss untuk setiap threshold
    print(f'Threshold: {threshold:.2f}, Hamming Loss: {hamming_loss_value:.4f}')

# Plot grafik Hamming Loss
plt.figure(figsize=(10, 6))
plt.plot(thresholds, hamming_losses, marker='o', linestyle='-')
plt.title('Hamming Loss vs Threshold')
plt.xlabel('Threshold')
plt.ylabel('Hamming Loss')
plt.grid(True)
plt.show()

# Tampilkan hasil evaluasi keseluruhan
print(f'Test AUC: {avg_auc:.2f}, Test Precision:{precision:.2f}, Test Recall: {recall:.2f}')
# Out:
# 601/601 [==============================] - 3s 4ms/step
# Test AUC: 0.85
# Threshold: 0.10, Hamming Loss: 0.2372
# Threshold: 0.20, Hamming Loss: 0.1527
# Threshold: 0.30, Hamming Loss: 0.1249
# Threshold: 0.40, Hamming Loss: 0.1170
# Threshold: 0.50, Hamming Loss: 0.1154
# Threshold: 0.60, Hamming Loss: 0.1170
# Threshold: 0.70, Hamming Loss: 0.1222
# Threshold: 0.80, Hamming Loss: 0.1327
# Threshold: 0.90, Hamming Loss: 0.1510
# Test AUC: 0.85, Test Precision:0.79, Test Recall: 0.53

# %% [markdown]
# ## HASIL PREDIKSI

# %%
predictions = model.predict(X_test)

threshold = 0.5
predicted_labels = (predictions > threshold).astype(int)
predicted_df = pd.DataFrame(predicted_labels, columns=['Predicted_' + col for col in label_columns])

result_df = pd.concat([data, predicted_df], axis=1)
export_path = 'prediksi.xlsx'
result_df.to_excel(export_path, index=False)

print(f"prediksi {export_path}")

# %% [markdown]
# ## Cek Dengan kalimat baru

# %%
import numpy as np

# teks baru
new_text = "anies"

# tokenizer dan padding
new_sequence = tokenizer.texts_to_sequences([new_text])
new_padded = pad_sequences(new_sequence, maxlen=200)

# prediksi
new_prediction = model.predict(new_padded)
threshold = 0.5
new_predicted_labels = (new_prediction > threshold).astype(int)


emotion_labels = ['anger', 'anticipation', 'disgust', 'fear', 'joy', 'sadness', 'surprise', 'trust','anies','prabowo','ganjar']
predicted_emotions = [emotion_labels[i] for i, pred in enumerate(new_predicted_labels[0]) if pred == 1]

# Print hasil
print(f"prediksi: {', '.join(predicted_emotions)}")

# %% [markdown]
# ## Distribusi Label Emosi Paslon

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convert predicted_labels to DataFrame
predicted_labels_df = pd.DataFrame(predicted_labels, columns=['anies', 'prabowo', 'ganjar', 'anger', 'anticipation', 'disgust', 'fear', 'joy', 'sadness', 'surprise', 'trust'])

# Plot label distribution for each politician
politicians = ['anies', 'prabowo', 'ganjar']

# Set up the grid for subplots
fig, axes = plt.subplots(nrows=1, ncols=len(politicians), figsize=(15, 6))

for i, politician in enumerate(politicians):
    # Filter data for the current politician
    politician_data = predicted_labels_df[predicted_labels_df[politician] == 1]
    # Drop politician columns to focus only on emotions
    politician_data = politician_data.drop(columns=politicians)
    
    # Calculate label distribution for emotions
    emotion_distribution = politician_data.sum()
    
    # Plot the distribution
    sns.barplot(x=emotion_distribution.index, y=emotion_distribution.values, palette='Blues', ax=axes[i])
    axes[i].set_title(f'Emotion Label Distribution for {politician.capitalize()}')
    axes[i].set_xlabel('Emotions')
    axes[i].set_ylabel('Frequency')
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5 Kalimat yang mengiterpretasikan EMOSI tiap PASLON

# %%
import pandas as pd

# Load the data
# Misalkan Anda memiliki file CSV yang berisi data
data_path = "augmentasifix.xlsx"
predicted_labels_df = pd.read_excel(data_path)

# Define the list of emotions
emotions = ['anger', 'anticipation', 'disgust', 'fear', 'joy', 'sadness', 'surprise', 'trust']

# Function to extract example sentences for each emotion for a given politician
def extract_example_sentences(data, politician):
    example_sentences = {}
    for emotion in emotions:
        # Filter data for the current politician and emotion
        politician_emotion_data = data[(data[politician] == 1) & (data[emotion] == 1)]
        # Sort the data by the probability of the emotion in descending order
        politician_emotion_data_sorted = politician_emotion_data.sort_values(by=emotion, ascending=False)
        # Take the top 3 example sentences for the current emotion
        example_sentences[emotion] = politician_emotion_data_sorted.head(3)['formal_text'].tolist()
    return example_sentences

# List of politicians
politicians = ['anies', 'prabowo', 'ganjar']

# Iterate through each politician
for politician in politicians:
    print(f"Politician: {politician.capitalize()}")
    # Filter data for the current politician
    politician_data = predicted_labels_df[predicted_labels_df[politician] == 1]
    example_sentences = extract_example_sentences(politician_data, politician)
    # Print example sentences for each emotion
    for emotion, sentences in example_sentences.items():
        if sentences:
            print(f"{emotion.capitalize()}:")
            for sentence in sentences:
                print(f"- {sentence}")
    print()

# %% [markdown]
# ## SNA

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# Load data
data_path = 'Update_Data.xlsx'
data = pd.read_excel(data_path)

# Membuat graf
G = nx.Graph()

# Menambahkan nodes untuk tokoh politik dan emosi
politicians = ['anies', 'prabowo', 'ganjar']
emotions = ['anger', 'anticipation', 'disgust', 'fear', 'joy', 'sadness', 'surprise', 'trust']

# Menambahkan nodes dengan atribut
for politician in politicians:
    G.add_node(politician, color='blue', size=700, type='politician')

for emotion in emotions:
    G.add_node(emotion, color='red', size=500, type='emotion')

# Menambahkan edges berdasarkan jumlah komentar yang mengasosiasikan tokoh dengan emosi tertentu
for emotion in emotions:
    for politician in politicians:
        weight = data[data[politician] == 1][emotion].sum()
        if weight > 0:
            G.add_edge(politician, emotion, weight=weight)

# Mengatur warna dan ukuran node
node_colors = [G.nodes[node]['color'] for node in G]
node_sizes = [G.nodes[node]['size'] for node in G]

# Mengatur lebar garis berdasarkan bobot
edge_widths = [edgedata['weight'] / 300 for _, _, edgedata in G.edges(data=True)]

# Menggunakan layout yang lebih menarik
pos = nx.spring_layout(G, k=0.15, iterations=20)

# Menggambar graf dengan visualisasi yang lebih baik
plt.figure(figsize=(14, 12))
nx.draw(G, pos, node_color=node_colors, node_size=node_sizes, width=edge_widths,
        with_labels=True, font_size=12, font_color='white', edge_color='#FF5733')
plt.title("Emotional Associations with Political Figures")
plt.show()
